# %%
#importing important libraries

# basic libraries
import pandas as pd #data wrangling
import numpy as np #numerical computation
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

#data visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#importing the data

df = pd.read_csv(r'C:\Users\KIIT\Desktop\Lexis_100K_v4.csv')
df.head()
# Out:
#              CID  Total_bank_products                        Products  \
# 0  CUST_ID000001                    2  Savings Account, Fixed Deposit
# 1  CUST_ID000003                    1                 Savings Account
# 2  CUST_ID000005                    1                 Savings Account
# 3  CUST_ID000006                    2  Savings Account, Fixed Deposit
# 4  CUST_ID000007                    1                 Savings Account
#
#    CREDIT_SCORE  CUSTOMER_RATING  Num_Dependents  PinCode_rating  \
# 0           713              2.1               4               2
# 1           700              2.0               4               3
# 2           536              3.8               4               0
# 3           732              2.1               1               0
# 4           800              2.0               2               8
#
#   IsOnlineBankingUser IsSmsBankingUser IsChequeBookUser  ...  \
# 0                  No               No              Yes  ...
# ...

# %%
df['Life-Insurance_Cross-Sell prediction'].value_counts()
# Out:
# Life-Insurance_Cross-Sell prediction
# 0    57052
# 1    42948
# Name: count, dtype: int64

# %%
# checking the shape of the data
print(df.shape) #number of rows and columns ( 1 being the target column )
# Out:
# (100000, 49)

# %%
#checking the null values
df.isnull().sum()
# Out:
# CID                                           0
# Total_bank_products                           0
# Products                                      0
# CREDIT_SCORE                                  0
# CUSTOMER_RATING                               0
# Num_Dependents                                0
# PinCode_rating                                0
# IsOnlineBankingUser                           0
# IsSmsBankingUser                              0
# IsChequeBookUser                              0
# Organisation_type                             0
# Marital_Status                                0
# Monthly_Income                                0
# DTI                                           0
# Is_app_user                                   0
# Total_Experience                              0
# months_current_job                            0
# Existing_Customer_Since_When                  0
# Type_of_employment                            0
# Education                                     0
# ...

# %%
# dropping a column
df = df.drop('CID', axis=1)
df.head()
# Out:
#    Total_bank_products                        Products  CREDIT_SCORE  \
# 0                    2  Savings Account, Fixed Deposit           713
# 1                    1                 Savings Account           700
# 2                    1                 Savings Account           536
# 3                    2  Savings Account, Fixed Deposit           732
# 4                    1                 Savings Account           800
#
#    CUSTOMER_RATING  Num_Dependents  PinCode_rating IsOnlineBankingUser  \
# 0              2.1               4               2                  No
# 1              2.0               4               3                 Yes
# 2              3.8               4               0                 Yes
# 3              2.1               1               0                 Yes
# 4              2.0               2               8                 Yes
#
#   IsSmsBankingUser IsChequeBookUser Organisation_type  ...  \
# 0               No              Yes       mnc/kpo/bpo  ...
# ...

# %%
# printing the shape again
print(df.shape)
# Out:
# (100000, 48)

# %%
# getting proportion of different categories in marital status
df['Marital_Status'].value_counts()
# Out:
# Marital_Status
# Married     48359
# Single      44937
# Divorced     6704
# Name: count, dtype: int64

# %%
df['Type_of_employment'].value_counts()
# Out:
# Type_of_employment
# Salaried    100000
# Name: count, dtype: int64

# %%
df['Education'].value_counts()
# Out:
# Education
# Master         38711
# High School    35089
# Bachelor       14959
# PhD            11241
# Name: count, dtype: int64

# %%
df['Balance_Trend_Segment'].value_counts()
# Out:
# Balance_Trend_Segment
# Decreasing    48352
# Increasing    28911
# Steady        22737
# Name: count, dtype: int64

# %%
# getting proportions of values in target variable
df['Life-Insurance_Cross-Sell prediction'].value_counts()
# Out:
# Life-Insurance_Cross-Sell prediction
# 0    57052
# 1    42948
# Name: count, dtype: int64

# %%
57052/(57052+42948)
# Out:
# 0.57052

# %%
#Standard scaler

# backup
df_ready=df.copy() # since undo is not there in python

# importing other important libraries
from sklearn.preprocessing import StandardScaler

# Initialization
Scaler = StandardScaler()

# Making a list of numerical columns
num_cols=['CREDIT_SCORE' ,'CUSTOMER_RATING','Monthly_Income','DTI',
          'Total_Experience','months_current_job','Existing_Customer_Since_When'
          ,'Avg Balance','Count_minimum_balance_Total','Savings_Account_Total',
          'Savings_Account_Cable Bill_Total','Savings_Account_Dining_Total','Savings_Account_Electricity Bill_Total','Savings_Account_Entertainment_Total',
          'Savings_Account_Gas Bill_Total','Savings_Account_Gasoline/Fuel_Total','Savings_Account_Grocery_Total','Savings_Account_Internet Bill_Total',
         'Savings_Account_Merchant_Total','Savings_Account_Mobile Recharge_Total','Savings_Account_Pharmacy/Healthcare_Total','Savings_Account_Shopping_Total',
          'Savings_Account_Telephone Bill_Total','Savings_Account_Ticket Booking_Total','Savings_Account_Travel_Total','Savings_Account_Water Bill_Total',
         'Savings_Account_Wellness and Fitness_Total','Savings_Churn_Predicted_Label']

# scaling
df_ready[num_cols] = Scaler.fit_transform(df_ready[num_cols])
df_ready.head()
# Out:
#    Total_bank_products                        Products  CREDIT_SCORE  \
# 0                    2  Savings Account, Fixed Deposit      0.238568
# 1                    1                 Savings Account      0.101974
# 2                    1                 Savings Account     -1.621216
# 3                    2  Savings Account, Fixed Deposit      0.438206
# 4                    1                 Savings Account      1.152699
#
#    CUSTOMER_RATING  Num_Dependents  PinCode_rating IsOnlineBankingUser  \
# 0        -0.504538               4               2                  No
# 1        -0.689250               4               3                 Yes
# 2         2.635570               4               0                 Yes
# 3        -0.504538               1               0                 Yes
# 4        -0.689250               2               8                 Yes
#
#   IsSmsBankingUser IsChequeBookUser Organisation_type  ...  \
# 0               No              Yes       mnc/kpo/bpo  ...
# ...

# %%
print(df_ready['Life-Insurance_Cross-Sell prediction'])
# Out:
# 0        1
# 1        0
# 2        1
# 3        0
# 4        0
#         ..
# 99995    0
# 99996    0
# 99997    1
# 99998    1
# 99999    0
# Name: Life-Insurance_Cross-Sell prediction, Length: 100000, dtype: int64

# %%
# dealing with categorical columns

# list of categorical columns
cat_cols = ['Products','Organisation_type','Marital_Status','Type_of_employment','Education','Balance_Trend_Segment']

# Encoding
df_ready = pd.get_dummies(data = df_ready, columns = cat_cols)


# encoding other yes no values of dataset
df_ready['IsOnlineBankingUser'] = df_ready['IsOnlineBankingUser'].apply(lambda x : 1 if x =='yes' else 0)
df_ready['IsSmsBankingUser'] = df_ready['IsSmsBankingUser'].apply(lambda x : 1 if x =='yes' else 0)
df_ready['IsChequeBookUser'] = df_ready['IsChequeBookUser'].apply(lambda x : 1 if x =='yes' else 0)
df_ready['Is_app_user'] = df_ready['Is_app_user'].apply(lambda x : 1 if x =='yes' else 0)
df_ready['Is_Life_Insurance_Holder'] = df_ready['Is_Life_Insurance_Holder'].apply(lambda x : 1 if x =='yes' else 0)

df_ready.head()
# Out:
#    Total_bank_products  CREDIT_SCORE  CUSTOMER_RATING  Num_Dependents  \
# 0                    2      0.238568        -0.504538               4
# 1                    1      0.101974        -0.689250               4
# 2                    1     -1.621216         2.635570               4
# 3                    2      0.438206        -0.504538               1
# 4                    1      1.152699        -0.689250               2
#
#    PinCode_rating  IsOnlineBankingUser  IsSmsBankingUser  IsChequeBookUser  \
# 0               2                    0                 0                 0
# 1               3                    0                 0                 0
# 2               0                    0                 0                 0
# 3               0                    0                 0                 0
# 4               8                    0                 0                 0
#
#    Monthly_Income       DTI  ...  Marital_Status_Married  \
# ...

# %%
print(df_ready['Life-Insurance_Cross-Sell prediction'])
# Out:
# 0        1
# 1        0
# 2        1
# 3        0
# 4        0
#         ..
# 99995    0
# 99996    0
# 99997    1
# 99998    1
# 99999    0
# Name: Life-Insurance_Cross-Sell prediction, Length: 100000, dtype: int64

# %%
# printing the shape of data
print(df_ready.shape)
# Out:
# (100000, 102)

# %%
# seperating input and output features

# input feature
features = df_ready.drop('Life-Insurance_Cross-Sell prediction',axis = 1)

# target
target = df_ready['Life-Insurance_Cross-Sell prediction']

# %%
# Train Test Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features, target, 
                                                    test_size = 0.2, random_state = 7)

# %%
# logistic regression

# %%
#model
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(max_iter = 1000000) 
# maximum number of iterations in the gradient descent step is 10^6 

# fitting the model
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000000)

# %%
df_ready.head()
# Out:
#    Total_bank_products  CREDIT_SCORE  CUSTOMER_RATING  Num_Dependents  \
# 0                    2      0.238568        -0.504538               4
# 1                    1      0.101974        -0.689250               4
# 2                    1     -1.621216         2.635570               4
# 3                    2      0.438206        -0.504538               1
# 4                    1      1.152699        -0.689250               2
#
#    PinCode_rating  IsOnlineBankingUser  IsSmsBankingUser  IsChequeBookUser  \
# 0               2                    0                 0                 0
# 1               3                    0                 0                 0
# 2               0                    0                 0                 0
# 3               0                    0                 0                 0
# 4               8                    0                 0                 0
#
#    Monthly_Income       DTI  ...  Marital_Status_Married  \
# ...

# %%
print(df_ready['Life-Insurance_Cross-Sell prediction'])
# Out:
# 0        1
# 1        0
# 2        1
# 3        0
# 4        0
#         ..
# 99995    0
# 99996    0
# 99997    1
# 99998    1
# 99999    0
# Name: Life-Insurance_Cross-Sell prediction, Length: 100000, dtype: int64

# %%
# Predicting from the model
y_pred = lr.predict(X_test)

# %%
# Evaluation
from sklearn.metrics import accuracy_score
print('Accuracy:',accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.82925

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[9673, 1787],
#        [1628, 6912]], dtype=int64)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.84      0.85     11460
#            1       0.79      0.81      0.80      8540
#
#     accuracy                           0.83     20000
#    macro avg       0.83      0.83      0.83     20000
# weighted avg       0.83      0.83      0.83     20000
